# %%
import requests

# %%
url = 'https://www.pagina12.com.ar/'

# %%
p12 = requests.get(url)  ##De esta forma descargamos la pagina web

# %%
p12.status_code ##Verificamos el statuscode.
# Out:
# 200

# %%
print(p12.text) ##imprmimos el texto
# Out:
# <!DOCTYPE html><html class="no-js"><head><meta charset="utf-8"><title>Página12 | La otra mirada</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","url": "https://www.pagina12.com.ar","logo": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png"}</script><meta property="description" name="description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="fb:pages" name="fb:pages" content="1541638399393436"><meta property="og:locale" name="og:locale" content="es_AR"><meta property="og:title" name="og:title" content="Página12 | La otra mirada"><meta property="og:site_name" name="og:site_name" content="PAGINA12"><meta property="og:type" name="og:type" content="website"><meta property="og:url" name="og:url" content="https://www.pagina12.com.ar"><meta property="og:description" name="og:description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="twitter:title" name="twitter:title" content="Página12 | La otra mirada"><meta property="twitter:description" name="twitter:description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="twitter:creator" name="twitter:creator" content="@Pagina12"><meta property="twitter:site" name="twitter:site" content="@pagina12"><meta property="article:author" name="article:author" content="Página12"><meta property="article:publisher" name="article:publisher" content="https://www.facebook.com/Pagina12ok"><meta name="share_cdn_host" content="https://www.pagina12.com.ar"><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, user-scalable=yes" /><link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/jquery.slick/1.6.0/slick.css"><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/main.min.css?v=1.0.195" media="screen"><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/print.min.css?v=1.0.195" media="print"><link rel="shortcut icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.195" type="image/x-icon"><link rel="icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.195" type="image/x-icon"><link rel="apple-touch-icon" sizes="57x57" href="https://www.pagina12.com.ar/assets/media/favicon/57x57.png?v=1.0.195"><link rel="apple-touch-icon" sizes="72x72" href="https://www.pagina12.com.ar/assets/media/favicon/72x72.png?v=1.0.195"><link rel="apple-touch-icon" sizes="114x114" href="https://www.pagina12.com.ar/assets/media/favicon/114x114.png?v=1.0.195"><link rel="apple-touch-icon" sizes="120x120" href="https://www.pagina12.com.ar/assets/media/favicon/120x120.png?v=1.0.195"><link rel="apple-touch-icon" sizes="144x144" href="https://www.pagina12.com.ar/assets/media/favicon/144x144.png?v=1.0.195"><link rel="apple-touch-icon" sizes="152x152" href="https://www.pagina12.com.ar/assets/media/favicon/152x152.png?v=1.0.195"><script>dataLayer = [];dataLayer.push({"section": "home"});dataLayer.push({"suplement": "home"});dataLayer.push({"listing": "home"});dataLayer.push({"search": "-"});dataLayer.push({"author": "-"});dataLayer.push({"id": "-"});dataLayer.push({"module": "p12_home"});dataLayer.push({"enviroment": "production"});dataLayer.push({"userLoggedIn": "0"});dataLayer.push({"userContributor": "0"});</script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-THCQP5X');</script><script type='text/javascript'>(function() {var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});_sf_async_config['uid'] = 65120;_sf_async_config['domain'] = 'pagina12.com.ar';_sf_async_config['flickerControl'] = false; ...
# @media only screen and (max-width: 464px)  { #interactivo-corona { height: 240px; margin-top: 5px; }}
# @media only screen and (min-width: 465px) and (max-width: 768px)  { #interactivo-corona { height: 205px; }}
# @media only screen and (min-width: 1557px) { #interactivo-corona { height: 124px; }</style><div class="wrapper"><div class="layout-region region-1 moderna"><div class="headlines-group"><div class="columns small-12 medium-6 medium-push-3 "> <div class="headline-card headline-featured-1 moderna"><article><div class="column reverse"><div class="rows xsmall-12 medium-12"><div class="headline-content"><div class="article-title"><a href="https://www.pagina12.com.ar/258745-la-cuarentena-seguira-otras-dos-semanas"><div class="element title-prefix">El Presidente extenderá el aislamiento</div><div class="element title">La cuarentena seguirá otras dos semanas</div><div class="element title-suffix">Alberto Fernández lo decidió con sus funcionarios en Olivos. Esta tarde recibirá nuevamente a los sanitaristas y luego definirá los detalles de la continuidad de la medida.</div></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a class="no-link">Fernando Cibeira</a></span></div></div></div><div class="rows xsmall-12 medium-12"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/258745-la-cuarentena-seguira-otras-dos-semanas"><div class="intrinsic-container"><img class="show-for-small-only  " src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/media/articles/64228/whatsapp-20image-202020-04-09-20at-2021-03-12.jpeg?itok=65y1LtE1" alt="Alberto Fernández con sus funcionarios en Olivos y la pantalla con los datos de la pandemia detrás."><img class="show-for-medium-only  " src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/media/articles/64228/whatsapp-20image-202020-04-09-20at-2021-03-12.jpeg?itok=EYJrid9U" alt="Alberto Fernández con sus funcionarios en Olivos y la pantalla con los datos de la pandemia detrás."><img class="show-for-large-only  " src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/media/articles/64228/whatsapp-20image-202020-04-09-20at-2021-03-12.jpeg?itok=EYJrid9U" alt="Alberto Fernández con sus funcionarios en Olivos y la pantalla con los datos de la pandemia detrás."><img class="show-for-xsmall-only  " src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/media/articles/64228/whatsapp-20image-202020-04-09-20at-2021-03-12.jpeg?itok=YLVEIMYM" alt="Alberto Fernández con sus funcionarios en Olivos y la pantalla con los datos de la pandemia detrás."><img class="show-for-xlarge  " src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/media/articles/64228/whatsapp-20image-202020-04-09-20at-2021-03-12.jpeg?itok=EYJrid9U" alt="Alberto Fernández con sus funcionarios en Olivos y la pantalla con los datos de la pandemia detrás."></div></a></div></div></div></article></div></div><div class="columns small-12 medium-3 medium-pull-6"><div class="row headline-featured-1 white-bg moderna "> <div class="headline-card headline-1 "><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/258705-ahora-el-conflicto-estallo-entre-los-intendentes-del-macrism"><div class="intrinsic-container"><img class="show-for-small-only  " src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/media/articles/64080/whatsapp-20image-202020-04-09-20at-2018-07-40.jpeg?itok=2-V0wHYo" alt=""><img class="show-for-medium-only  " src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/media/articles/64080/whatsapp-20image-202020-04-09-20at-2018-07-40.jpeg?itok=QVzBTr1B" alt=""><img class="show-for-large-only  " src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/media/articles/64080/whatsapp-20image-202020-04-09-20at-2018-07-40.jpeg?itok=2-V0wHYo" alt=""><img class="show-for-xsmall-only  " src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/media/articles/64080/whatsapp-20image-202020-04-09-20at-2018-07-40.jpeg?itok=hligAtN5" alt=""><img class="show-for-xlarge  " src="https://images.pagin ...
# </div></div></div><div class="_text"><a href="https://www.pagina12.com.ar/258682-la-crisis-economica-mundial-que-generara-el-coronavirus"><span>La crisis económica mundial que generará el coronavirus</span> | La explicación de Alfredo Zaiat sobre el impacto global de la pandemia</a></div></div></div></div><script>var elAudioVisual = document.getElementById('audiovisual_258682');var player=document.getElementById('audiovisuales-player');player.appendChild(elAudioVisual.childNodes[0]);window._AUDIOVISUAL_SELECTED_ = 258682;</script><div class="_element" onclick="if(window._AUDIOVISUAL_SELECTED_ === 255520){return false;}var elAudioVisual = document.getElementById('audiovisual_255520');var player=document.getElementById('audiovisuales-player');var oldElAudioVisual = document.getElementById('audiovisual_'+window._AUDIOVISUAL_SELECTED_);var jwplay=player.getElementsByClassName('jwplayer');if(jwplay.length){jwplayer(jwplay[1].id).stop();}oldElAudioVisual.appendChild(player.childNodes[0]);player.innerHTML='';player.appendChild(elAudioVisual.childNodes[0]);window._AUDIOVISUAL_SELECTED_=255520;if( window.innerWidth < 768){var yOffset = player.offsetTop;window.scrollTo(0, yOffset-20);}"><div class="audiovisuales-img"><div class="audiovisuales-img-inner"><div class="play-icon"></div><img title="El surfer que violó la cuarentena" src="https://images.pagina12.com.ar/styles/focal130x98/public/2020-03/capture_0.JPG?itok=xxZtAbZV" /></div></div><div class="_text">El surfer que violó la cuarentena</div><div id="audiovisual_255520" class="_embedded"><div><div class="multimedia-container-wrapper"><div class="multimedia-container marginBottom"><div class="video-embed-field-responsive-video"><iframe name="9d8620dee84e906dcb0ba64dc85c939e" width="854" height="480" frameborder="0" allowfullscreen="allowfullscreen" src="https://www.youtube.com/embed/nYL0g-6D_0Y?autoplay=0&amp;start=0&amp;rel=0&amp;enablejsapi=1"></iframe>
# </div></div></div><div class="_text"><a href="https://www.pagina12.com.ar/255520-el-surfer-que-violo-la-cuarentena"><span>El surfer que violó la cuarentena</span></a></div></div></div></div><div class="_element" onclick="if(window._AUDIOVISUAL_SELECTED_ === 253928){return false;}var elAudioVisual = document.getElementById('audiovisual_253928');var player=document.getElementById('audiovisuales-player');var oldElAudioVisual = document.getElementById('audiovisual_'+window._AUDIOVISUAL_SELECTED_);var jwplay=player.getElementsByClassName('jwplayer');if(jwplay.length){jwplayer(jwplay[1].id).stop();}oldElAudioVisual.appendChild(player.childNodes[0]);player.innerHTML='';player.appendChild(elAudioVisual.childNodes[0]);window._AUDIOVISUAL_SELECTED_=253928;if( window.innerWidth < 768){var yOffset = player.offsetTop;window.scrollTo(0, yOffset-20);}"><div class="audiovisuales-img"><div class="audiovisuales-img-inner"><div class="play-icon"></div><img title="Mario Wainfeld analiza los primeros 100 días de Alberto Fernández" src="https://images.pagina12.com.ar/styles/focal130x98/public/2020-03/tapaaf100d.jpg?itok=jC6g0weq" /></div></div><div class="_text">Mario Wainfeld analiza los primeros 100 días de Alberto Fernández</div><div id="audiovisual_253928" class="_embedded"><div><div class="multimedia-container-wrapper"><div class="multimedia-container marginBottom"><div class="video-embed-field-responsive-video"><iframe name="0c3b16c138f86919e958327b2d0811b3" width="854" height="480" frameborder="0" allowfullscreen="allowfullscreen" src="https://www.youtube.com/embed/6FIIic6bLRQ?autoplay=0&amp;start=0&amp;rel=0&amp;enablejsapi=1"></iframe>
# </div></div></div><div class="_text"><a href="https://www.pagina12.com.ar/253928-mario-wainfeld-analiza-los-primeros-100-dias-de-alberto-fern"><span>Mario Wainfeld analiza los primeros 100 días de Alberto Fernández</span> | Un repaso desde el 10 de diciembre hasta la erupción del coronavirus</a></div></div></div></div><div class="_element" onclick="if(window._AUDIOVISUAL_SELECTED_ === 252728){return false;}var elAudioVisual = document.getElementById('audiovisual_252728');var player=document.getElementById('audiovisuales-player');var oldElAudioVisual = document.getElementById('audiovisual_'+window._AUDIOVISUAL_SELECTED_);var jwplay=player.getElementsByClassName('jwplayer');if(jwplay.length){jwplayer(jwplay[1].id).stop();}oldElAudioVisual.appendChild(player.childNodes[0]);player.innerHTML='';player.appendChild(elAudioVisual.childNodes[0]);window._AUDIOVISUAL_SELECTED_=252728;if( window.innerWidth < 768){var yOffset = player.offsetTop;window.scrollTo(0, yOffset-20);}"><div class="audiovisuales-img"><div class="audiovisuales-img-inner"><div class="play-icon"></div><img title="El mapa del dengue en Buenos Aires" src="https://images.pagina12.com.ar/styles/focal130x98/public/2020-03/capture.JPG?itok=dEdRTh4v" /></div></div><div class="_text">El mapa del dengue en Buenos Aires</div><div id="audiovisual_252728" class="_embedded"><div><div class="multimedia-container-wrapper"><div class="multimedia-container marginBottom"><div class="video-embed-field-responsive-video"><iframe name="55db4e60b2ac15a95076ea21a1b31c88" width="854" height="480" frameborder="0" allowfullscreen="allowfullscreen" src="https://www.youtube.com/embed/Cc5VO0oXKlU?autoplay=0&amp;start=0&amp;rel=0&amp;enablejsapi=1"></iframe>
# </div></div></div><div class="_text"><a href="https://www.pagina12.com.ar/252728-el-mapa-del-dengue-en-buenos-aires"><span>El mapa del dengue en Buenos Aires</span> | Más de 300 casos confirmados en la ciudad</a></div></div></div></div><div class="_element" onclick="if(window._AUDIOVISUAL_SELECTED_ === 253320){return false;}var elAudioVisual = document.getElementById('audiovisual_253320');var player=document.getElementById('audiovisuales-player');var oldElAudioVisual = document.getElementById('audiovisual_'+window._AUDIOVISUAL_SELECTED_);var jwplay=player.getElementsByClassName('jwplayer');if(jwplay.length){jwplayer(jwplay[1].id).stop();}oldElAudioVisual.appendChild(player.childNodes[0]);player.innerHTML='';player.appendChild(elAudioVisual.childNodes[0]);window._AUDIOVISUAL_SELECTED_=253320;if( window.innerWidth < 768){var yOffset = player.offsetTop;window.scrollTo(0, yOffset-20);}"><div class="audiovisuales-img"><div class="audiovisuales-img-inner"><div class="play-icon"></div><img title="Los rastros de la muerte y la antropología  " src="https://images.pagina12.com.ar/styles/focal130x98/public/media/articles/57815/eaaf.jpg?itok=qsdH8UsI" /></div></div><div class="_text">Los rastros de la muerte y la antropología  </div><div id="audiovisual_253320" class="_embedded"><div><div class="multimedia-container-wrapper"><div class="multimedia-container marginBottom"><div class="video-embed-field-responsive-video"><iframe name="ecfe2ff13a384e4f49ed110bf5631f9c" width="854" height="480" frameborder="0" allowfullscreen="allowfullscreen" src="https://www.youtube.com/embed/2qSeezeYF4k?autoplay=0&amp;start=0&amp;rel=0&amp;enablejsapi=1"></iframe>
# </div></div></div><div class="_text"><a href="https://www.pagina12.com.ar/253320-los-rastros-de-la-muerte-y-la-antropologia"><span>Los rastros de la muerte y la antropología  </span> | Un documental sobre la tarea del Equipo Argentino de Antropología Forense</a></div></div></div></div></div></div></div></div></div></div><div class="wrapper"><div class="expand-horizontal-sm"><div class="layout-region opinion-1 tradicional"><div class="title-box"><div class="title-box-deco"></div><div class="title-box_title"><div class="show-for-medium">Opinión</div><div class="hide-for-medium">Opinión</div></div><div class="title-box_btn"><a href="https://www.pagina12.com.ar/opinion"><div class="show-for-medium">Ver más notas de opinión</div><div class="hide-for-medium">Ver más notas</div></a></div></div><div class="row headlines-block white-bg"><div class="columns small-12 medium-3"><div class="headline-card headline-3 "><article class="headline-card-inner"><div class="block-content"><div class="headline-content"><div class="article-author-pic"><a href="https://www.pagina12.com.ar/autores/74230-boaventura-de-sousa-santos" class=""><img class="  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.195" data-src="https://images.pagina12.com.ar/styles/width300/public/2019-08/boaventura-de-sousa-santos-.png?itok=llrLwp6Y" alt=""></a></div><div class="article-title"><a href="https://www.pagina12.com.ar/258640-al-sur-de-la-cuarentena" "><div class="element title">Al Sur de la cuarentena</div></a></div><div class="article-author">Por <a href="https://www.pagina12.com.ar/autores/74230-boaventura-de-sousa-santos">Boaventura de Sousa Santos</a></div></div></div></article></div></div><div class="columns small-12 medium-3"><div class="headline-card headline-3 "><article class="headline-card-inner"><div class="block-content"><div class="headline-content"><div class="article-author-pic"><a href="https://www.pagina12.com.ar/autores/24348-eva-giberti" class=""><img class="  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.195" data-src="https://images.pagina12.com.ar/styles/width300/public/2017-03/eva-giberti.png?itok=LS_WyV3U" alt=""></a></div><div class="article-title"><a href="https://www.pagina12.com.ar/258465-el-pedido-de-kirchner-en-la-hora-actual" "><div class="element title">El pedido de Kirchner en la hora actual</div></a></div><div class="article-author">Por <a href="https://www.pagina12.com.ar/autores/24348-eva-giberti">Eva Giberti</a></div></div></div></article></div></div><div class="columns small-12 medium-3"><div class="headline-card headline-3 "><article class="headline-card-inner"><div class="block-content"><div class="headline-content"><div class="article-author-pic"><a href="https://www.pagina12.com.ar/autores/146310-nora-merlin" class=""><img class="  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.195" data-src="https://images.pagina12.com.ar/styles/width300/public/2019-07/nora-merlin.png?itok=8KGpLuLE" alt=""></a></div><div class="article-title"><a href="https://www.pagina12.com.ar/258459-coronavirus-y-transferencia" "><div class="element title">Coronavirus y transferencia</div></a></div><div class="article-author">Por <a href="https://www.pagina12.com.ar/autores/146310-nora-merlin">Nora Merlin</a></div></div></div></article></div></div><div class="columns small-12 medium-3"><div class="headline-card headline-3 "><article class="headline-card-inner"><div class="block-content"><div class="headline-content"><div class="article-author-pic"><a href="https://www.pagina12.com.ar/autores/1856-mempo-giardinelli" class=""><img class="  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.195" data-src="https://images.pagina12.com.ar/styles/width300/public/2018-01/mempo-giardinelli2_0.png?itok=xBLMKj9j" alt=""></a></div><div class="article-title"><a href="https://www.pagina12.com.ar/257770-de-pestes-fantasmas-y-m ...
# "><li class="twitter"><span class="share fonticon-twitter"></span></li><li class="facebook"><span class="share fonticon-facebook"></span></li><li class="mail"><span class="share fonticon-mail"></span></li></li></ul></div><div class="pirulo-label"><div class="pirulo-label-deco"></div><a href="https://www.pagina12.com.ar/pirulo/258757">CHOCHA</a></div></div><div class="pirulo-block-middle"><p>El dirigente radical Ricardo Alfonsín volvió a cuestionar la postura de la UCR, en este caso respecto a la crisis generada por el coronavirus y las herramientas para combatirla: “¿Qué espera el partido para apoyar la creación de un impuesto a las grandes fortunas de la Argentina pensado con el fin de recaudar fondos destinados a enfrentar la pandemia y la pospandemia, y para condenar a los que aprovechan su poder de mercado y suben los precios, y repudiar la venta de productos en mal estado? ¿Creerán que la gente está chocha con esto?”.</p>
# </div><div class="pirulo-block-bottom"><div class="pirulo-social hide-for-large"><ul class="social-media big" share-data="pirulo" share-url="https://www.pagina12.com.ar/pirulo/258757" share-title="CHOCHA" share-desc="El dirigente radical Ricardo Alfonsín volvió a cuestionar la postura de la UCR, en este caso respecto a la crisis generada por el coronavirus y las herramientas para combatirla: “¿Qué espera el partido para apoyar la creación de un impuesto a las gr..." share-img="https://www.pagina12.com.ar/assets/media/FallBack-Logo.jpg" share-body="&lt;p&gt;El dirigente radical Ricardo Alfonsín volvió a cuestionar la postura de la UCR, en este caso respecto a la crisis generada por el coronavirus y las herramientas para combatirla: “¿Qué espera el partido para apoyar la creación de un impuesto a las grandes fortunas de la Argentina pensado con el fin de recaudar fondos destinados a enfrentar la pandemia y la pospandemia, y para condenar a los que aprovechan su poder de mercado y suben los precios, y repudiar la venta de productos en mal estado? ¿Creerán que la gente está chocha con esto?”.&lt;/p&gt;
# "><li class="twitter"><span class="share fonticon-twitter big"></span></li><li class="facebook"><span class="share fonticon-facebook big"></span></li><li class="mail"><span class="share fonticon-mail big"></span></li><li class="whatsapp hide-for-medium"><span class="share fonticon-whatsapp big"></span></li><li class="telegram hide-for-medium"><span class="share fonticon-telegram big"></span></li></ul></div></div></div></div></div></div></div></div><div class="text-center iframe-margin-top hide-for-medium"><div id="div-gpt-ad-1506537706019-0"></div></div></div><div class="wrapper"><div class="expand-horizontal-sm"><div class="layout-region region-2x2 tradicional sm-horiz"><div class="row headlines-block"><div class="headlines-block-col fixed-w left flex show-for-large"><div class="central bottom-auto ad-bg ad-bg--600"><div id="div-gpt-ad-1519672027502-0"></div></div></div><div class="headlines-block-col dynamic-w"><div class="headlines-block-row"><div class="small-12 medium-6 headline-list-mobile"> <div class="headline-card headline-2 "><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/258720-inversion-millonaria-para-atenuar-la-crisis"><div class="intrinsic-container"><img class="show-for-small-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.195" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/media/articles/64197/auh.jpg?itok=GqdeJDqL" alt="La principal preocupación del Gobierno fue proteger a los segmentos más vulnerables de la población. "><img class="show-for-medium-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.195" data-src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/media/articles/64197/auh.jpg?itok=KOm21HRH" alt="La principal preocupación del Gobierno fue proteger a los segmentos más vulnerables de la población. "><img class="show-for-large-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.195" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/media/articles/64197/auh.jpg?itok=GqdeJDqL" alt="La principal preocupación del Gobierno fue proteger a los segmentos más vulnerables de la población. "><img class="show-for-xsmall-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.195" data-src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/media/articles/64197/auh.jpg?itok=Z2cTHj5M" alt="La principal preocupación del Gobierno fue proteger a los segmentos más vulnerables de la población. "><img class="show-for-xlarge  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.195" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/media/articles/64197/auh.jpg?itok=GqdeJDqL" alt="La principal preocupación del Gobierno fue proteger a los segmentos más vulnerables de la población. "></div></a></div></div><div class="block-content"><div class="headline-content"><div class="article-title lg "><a href="https://www.pagina12.com.ar/258720-inversion-millonaria-para-atenuar-la-crisis" ">Inversión millonaria para atenuar la <span class="title-separator">crisis</span><span class="title-prefix">El gobierno desembolsó más de 550 mil millones de pesos</span></a></a></div><div class="time-author-wrapper article-ta "></div></div></div></article></div></div><div class="small-12 medium-6 headline-list-mobile"> <div class="headline-card headline-2 "><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/258653-el-virus-no-discrimina-no-discriminemos-nosotros"><div class="intrinsic-container"><img class="show-for-small-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.195" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/pub ...
# la pandemia de coronavirus</span><span class="title-separator"></span><span class="element title-prefix">INFORME  </span></a></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a class="no-link">Gabriela Naso</a></span></div></div></article></div> <div class="headline-card headline-6 "><article class="headline-card-inner"><div class="headline-content"><div class="article-title "><a href="https://www.pagina12.com.ar/256750-videojuegos-una-pulseada-entre-el-diseno-y-la-narracion" "><span>VIDEOJUEGOS: UNA PULSEADA ENTRE EL DISEÑO Y LA NARRACIÓN</span><span class="title-separator"></span><span class="element title-prefix">GUILLERMO CRESPI </span></a></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a class="no-link">Fernando Núñez</a></span></div></div></article></div> <div class="headline-card headline-6 "><article class="headline-card-inner"><div class="headline-content"><div class="article-title "><a href="https://www.pagina12.com.ar/256754-malvinas-una-cuestion-de-estado" "><span>Malvinas, una cuestión de Estado</span><span class="title-separator"></span><span class="element title-prefix">SOBERANÍA </span></a></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a class="no-link">Gabriela Naso</a></span></div></div></article></div></div></div></div></div><div class="row headlines-block show-for-medium"><div class="row-wrapper"><div class="xsmall-12 medium-4 column"><div class="suplemento-wrapper"><div class="title-box"><a href="https://www.pagina12.com.ar/suplementos/soy"><div class="title-img-wrapper"><img src="https://www.pagina12.com.ar/assets/media/logos/logo_soy_n.svg?v=1.0.195" alt="Soy" /></div></a><div class="title-box_btn"><a href="https://www.pagina12.com.ar/suplementos/soy">Ver más</a></div></div><a href="https://www.pagina12.com.ar/suplementos/soy"><img src="https://images.pagina12.com.ar/styles/focal_content_458x609/public/2020-04/supplement/fototapasoy_0.jpg?itok=gKOCc81b" alt="Y vos... ¿cómo la estás llevando?"></a><div class="headline-suplemento"><div class="headline-suplemento-inner"><div class="headline-suplemento-content"><div class="article-title lg"><a href="https://www.pagina12.com.ar/suplementos/soy">Y vos... ¿cómo la estás llevando?<span class="title-prefix">&nbsp;|&nbsp;Historias de cuarentena desde Neuquén a Formosa</span></a></div></div></div></div> <div class="headline-card headline-6 "><article class="headline-card-inner"><div class="headline-content"><div class="article-title "><a href="https://www.pagina12.com.ar/258086-coronavirus-para-aislarse-bien-hay-que-venir-al-sur" "><span>Coronavirus: Para aislarse bien hay que venir al sur</span><span class="title-separator"></span><span class="element title-prefix">Cuarentena en Aluminé, Neuquén</span></a></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a class="no-link">Malén Otaño</a></span></div></div></article></div> <div class="headline-card headline-6 "><article class="headline-card-inner"><div class="headline-content"><div class="article-title "><a href="https://www.pagina12.com.ar/258361-coronavirus-y-paranoia-la-enfermedad-como-excusa-para-la-hum" "><span>Coronavirus y paranoia: la enfermedad como excusa para la humillación </span><span class="title-separator"></span><span class="element title-prefix">La pandemia en los medios: en nombre de la salud, la barbarie </span></a></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a href="https://www.pagina12.com.ar/autores/393-alejandro-modarelli">Alejandro Modarelli</a></span></div></div></article></div> <div class="headline-card headline-6 "><article class="headline-card-inner"><div class="headline-content"><div class="article-title "><a href="https://www.pagina12.com.ar/258340-algo-no-funciona-cicatrices-del-silencio-el-abuso-en-primera" "><span>Alg ...
# la pandemia de coronavirus</span><span class="title-separator"></span><span class="element title-prefix">INFORME  </span></a></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a class="no-link">Gabriela Naso</a></span></div></div></article></div> <div class="headline-card headline-6 "><article class="headline-card-inner"><div class="headline-content"><div class="article-title "><a href="https://www.pagina12.com.ar/256750-videojuegos-una-pulseada-entre-el-diseno-y-la-narracion" "><span>VIDEOJUEGOS: UNA PULSEADA ENTRE EL DISEÑO Y LA NARRACIÓN</span><span class="title-separator"></span><span class="element title-prefix">GUILLERMO CRESPI </span></a></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a class="no-link">Fernando Núñez</a></span></div></div></article></div> <div class="headline-card headline-6 "><article class="headline-card-inner"><div class="headline-content"><div class="article-title "><a href="https://www.pagina12.com.ar/256754-malvinas-una-cuestion-de-estado" "><span>Malvinas, una cuestión de Estado</span><span class="title-separator"></span><span class="element title-prefix">SOBERANÍA </span></a></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a class="no-link">Gabriela Naso</a></span></div></div></article></div></div></div></div></div></div><div class="ads-horizontal-expand iframe-margin-top show-for-medium"><div id="div-gpt-ad-1506534929675-0"></div></div></div><div class="wrapper"><div class="tema-1"><div class="layout-region tema producto moderna caras_y_caretas"><div class="row headlines-block headline-block-bg"><div class="headline-block-inner"><div class="columns small-12 medium-4"><a target="_blank" href="http://carasycaretas.org.ar/" class="image object-fit centered"><img src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif" class="lazyload  show-for-xsmall-only" data-src="https://images.pagina12.com.ar/styles/width470/public/2020-04/91887920-2993339954060700-3053398254814232576-o-jpg-nc-cat-101-nc-sid-8024bb-nc-ohc-bksz-sh1n4cax8m7bx5-nc-ht-scontent-faep4-1.jpg?itok=65_XskRb" alt="Tapa del suplemento" /><img src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif" class="lazyload  show-for-small-only" data-src="https://images.pagina12.com.ar/styles/width470/public/2020-04/91887920-2993339954060700-3053398254814232576-o-jpg-nc-cat-101-nc-sid-8024bb-nc-ohc-bksz-sh1n4cax8m7bx5-nc-ht-scontent-faep4-1.jpg?itok=65_XskRb" alt="Tapa del suplemento" /><img src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif" class="lazyload  show-for-medium-only" data-src="https://images.pagina12.com.ar/styles/width700/public/2020-04/91887920-2993339954060700-3053398254814232576-o-jpg-nc-cat-101-nc-sid-8024bb-nc-ohc-bksz-sh1n4cax8m7bx5-nc-ht-scontent-faep4-1.jpg?itok=H2Mk6_uH" alt="Tapa del suplemento" /><img src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif" class="lazyload  show-for-large-only" data-src="https://images.pagina12.com.ar/styles/width960/public/2020-04/91887920-2993339954060700-3053398254814232576-o-jpg-nc-cat-101-nc-sid-8024bb-nc-ohc-bksz-sh1n4cax8m7bx5-nc-ht-scontent-faep4-1.jpg?itok=8bxo3tL6" alt="Tapa del suplemento" /><img src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif" class="lazyload  show-for-xlarge" data-src="https://images.pagina12.com.ar/styles/width960/public/2020-04/91887920-2993339954060700-3053398254814232576-o-jpg-nc-cat-101-nc-sid-8024bb-nc-ohc-bksz-sh1n4cax8m7bx5-nc-ht-scontent-faep4-1.jpg?itok=8bxo3tL6" alt="Tapa del suplemento" /></a></div> <div class="rows small-12 medium-8"><div class="row small-12 medium-8" style=""><div class="columns small-12 medium-6 index-0"> <div class="headline-card headline-1 "><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://carasycaretas.org.ar/2020/04/04/la-hi ...

# %%
p12.content ##Entender el contenido
# Out:
# b'<!DOCTYPE html><html class="no-js"><head><meta charset="utf-8"><title>P\xc3\xa1gina12 | La otra mirada</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","url": "https://www.pagina12.com.ar","logo": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png"}</script><meta property="description" name="description" content="Notas focalizadas en el quehacer pol\xc3\xadtico de la Argentina."><meta property="fb:pages" name="fb:pages" content="1541638399393436"><meta property="og:locale" name="og:locale" content="es_AR"><meta property="og:title" name="og:title" content="P\xc3\xa1gina12 | La otra mirada"><meta property="og:site_name" name="og:site_name" content="PAGINA12"><meta property="og:type" name="og:type" content="website"><meta property="og:url" name="og:url" content="https://www.pagina12.com.ar"><meta property="og:description" name="og:description" content="Notas focalizadas en el quehacer pol\xc3\xadtico de la Argentina."><meta property="twitter:title" name="twitter:title" content="P\xc3\xa1gina12 | La otra mirada"><meta property="twitter:description" name="twitter:description" content="Notas focalizadas en el quehacer pol\xc3\xadtico de la Argentina."><meta property="twitter:creator" name="twitter:creator" content="@Pagina12"><meta property="twitter:site" name="twitter:site" content="@pagina12"><meta property="article:author" name="article:author" content="P\xc3\xa1gina12"><meta property="article:publisher" name="article:publisher" content="https://www.facebook.com/Pagina12ok"><meta name="share_cdn_host" content="https://www.pagina12.com.ar"><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, user-scalable=yes" /><link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/jquery.slick/1.6.0/slick.css"><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/main.min.css?v=1.0.195" media="screen"><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/print.min.css?v=1.0.195" media="print"><link rel="shortcut icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.195" type="image/x-icon"><link rel="icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.195" type="image/x-icon"><link rel="apple-touch-icon" sizes="57x57" href="https://www.pagina12.com.ar/assets/media/favicon/57x57.png?v=1.0.195"><link rel="apple-touch-icon" sizes="72x72" href="https://www.pagina12.com.ar/assets/media/favicon/72x72.png?v=1.0.195"><link rel="apple-touch-icon" sizes="114x114" href="https://www.pagina12.com.ar/assets/media/favicon/114x114.png?v=1.0.195"><link rel="apple-touch-icon" sizes="120x120" href="https://www.pagina12.com.ar/assets/media/favicon/120x120.png?v=1.0.195"><link rel="apple-touch-icon" sizes="144x144" href="https://www.pagina12.com.ar/assets/media/favicon/144x144.png?v=1.0.195"><link rel="apple-touch-icon" sizes="152x152" href="https://www.pagina12.com.ar/assets/media/favicon/152x152.png?v=1.0.195"><script>dataLayer = [];dataLayer.push({"section": "home"});dataLayer.push({"suplement": "home"});dataLayer.push({"listing": "home"});dataLayer.push({"search": "-"});dataLayer.push({"author": "-"});dataLayer.push({"id": "-"});dataLayer.push({"module": "p12_home"});dataLayer.push({"enviroment": "production"});dataLayer.push({"userLoggedIn": "0"});dataLayer.push({"userContributor": "0"});</script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\'//www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);})(window,document,\'script\',\'dataLayer\',\'GTM-THCQP5X\');</script><script type=\'text/javascript\'>(function() {var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});_sf_async_config[\'uid\'] = 65120;_sf_async_config[ ...

# %%
p12.headers
# Out:
# {'Date': 'Fri, 10 Apr 2020 13:52:20 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d829beea6f5b956f13a804946d85b0f5e1586526739; expires=Sun, 10-May-20 13:52:19 GMT; path=/; domain=.pagina12.com.ar; HttpOnly; SameSite=Lax', 'Vary': 'Accept-Encoding', 'X-DNS-Prefetch-Control': 'off', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains', 'X-Download-Options': 'noopen', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'X-Backend': 'prod_frontend_1', 'X-Backend-TTL': '180.000', 'X-Type': 'Dynamic URI', 'Age': '0', 'grace': '86400.000 none', 'ttl': '119.631', 'x-debug': '', 'X-Instance': 'cache-front-prod-varnish-76c5f88cf6-6j89c', 'x-restarts': '0', 'X-Cache': 'HIT (8)', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '581cf2987cbaf0a9-TPE', 'Content-Encoding': 'gzip'}

# %%
p12.request.headers ##encabezados con la solicitud que hacemos
# Out:
# {'User-Agent': 'python-requests/2.21.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
p12.request.method ##saber que metodo estamos utilizando
# Out:
# 'GET'

# %%
p12.request.url
# Out:
# 'https://www.pagina12.com.ar/'

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(p12.text, 'lxml') #separa el texto largo en partes pequenas para su manejo

# %%
print(soup.prettify()) ##Estrutura de la pagina

# %%
secciones = soup.find('ul', attrs={'class':'hot-sections'}).find_all('li') ##imprimimos el menu
secciones

# %%
seccion = secciones[1] ## obtenemos la primera seccion

# %%
seccion.a ## nos quedamos con el atributo a
# Out:
# <a href="https://www.pagina12.com.ar/secciones/economia">Economía</a>

# %%
seccion.a.get("href") ##obtenemos el link
# Out:
# 'https://www.pagina12.com.ar/secciones/economia'

# %%
seccion.a.get_text() ## obtenemos el texto
# Out:
# 'Economía'

# %%
links_secciones = [seccion.a.get('href') for seccion in secciones]

# %%
links_secciones

# %%
sec = requests.get(links_secciones[0])
sec.status_code
# Out:
# 200

# %%
s_seccion = BeautifulSoup(sec.text, 'lxml')
s_seccion

# %%
print(s_section.prettify())

# %% [markdown]
# ### Extraccion de listas de articulos

# %%
def obtener_notas(soup):
    lista_notas = []

    ##obtencion de articulo promocionado
    featured_article = soup.find('div', attrs={'class':'featured-article_container'}) 
    if featured_article:
      lista_notas.append(featured_article.a.get('href'))

    ##obtencion del listado de articulo
    article_list = soup.find('ul', attrs={'class':'article-list'})
    for article in article_list.find_all('li'):
      if article.a:
        lista_notas.append(article.a.get('href'))
    
    return lista_notas

# %%
lista_notas = obtener_notas(s_seccion)
lista_notas
# Out:
# ['https://www.pagina12.com.ar/258787-cuarentena-sigue-la-feria-judicial',
#  'https://www.pagina12.com.ar/258763-pagina-12-en-la-web',
#  'https://www.pagina12.com.ar/258502-detenida-por-circular-en-bicicleta-aparecio-ahorcada',
#  'https://www.pagina12.com.ar/258693-golpes-y-apremios-en-los-controles-por-la-cuarentena',
#  'https://www.pagina12.com.ar/258705-ahora-el-conflicto-estallo-entre-los-intendentes-del-macrism',
#  'https://www.pagina12.com.ar/258706-jaime-duran-barba-nunca-fui-funcionario-de-macri',
#  'https://www.pagina12.com.ar/258730-hay-que-evitar-los-margenes-para-lo-discrecional',
#  'https://www.pagina12.com.ar/258558-roque-perez-el-primer-municipio-bonaerense-en-recomendar-el-',
#  'https://www.pagina12.com.ar/258736-palos-y-balas-a-trabajadores-del-frigorifico-penta-en-bernal',
#  'https://www.pagina12.com.ar/258597-gobernadores-e-intendentes-comienzan-a-controlar-precios',
#  'https://www.pagina12.com.ar/258740-coronavirus-han-regresado-al-pais-154-mil-argentinos',
#  'https://www.pagina12.com.ar/258745-la-cuarentena-seguira-otras-dos-semanas',
#  'https://www.pagina12.com.ar/258609-el-gobernador-de-chubut-les-dio-una-palmadita-a-los-funciona',
#  'https://www.pagina12.com.ar/258622-abuelas-de-plaza-de-mayo-asegura-que-el-coronavirus-no-frena']

# %%
r = requests.get(url)

# %% [markdown]
# ### Manejo de errores

# %%
url_mala = url.replace('2', '3')

# %%
try:
  requests.get(url_mala)
except Exception as e:
  print('error en la request')
  print(e)

# %%
try:
  featured_article.a.get('href')
except:
  pass
  print('continua el codigo')

# %% [markdown]
# ### Descargar contenido

# %%
url_nota = lista_notas[0]
url_nota
# Out:
# 'https://www.pagina12.com.ar/258787-cuarentena-sigue-la-feria-judicial'

# %%
try:
  nota = requests.get(url_nota)
  if nota.status_code == 200:
    s_nota = BeautifulSoup(nota.text, 'lxml')
  ## extraemos el titulo
  title = s_nota.find('h1', attrs={'class': 'article-title'})
  print(title)

  ##Extraer la fecha
  fecha = s_nota.find('span', attrs={'pubdate':'pubdate'}).get('datetime')
  print(fecha)

  ##Extraer el autor
  autor = s_nota.find('div', attrs={'class':"article-author"}).a
  print(autor)


except Exception as e:
    print('error: ')
    print(e) 
    print('\n')
# Out:
# <h1 class="article-title">Cuarentena: ¿Sigue la feria judicial?</h1>
# 2020-04-10
# <a href="https://www.pagina12.com.ar/autores/180793-sofia-caram">Sofía Caram</a>

# %%
# Out:
# <h1 class="article-title">Cuarentena: ¿Sigue la feria judicial?</h1>
# 2020-04-10
